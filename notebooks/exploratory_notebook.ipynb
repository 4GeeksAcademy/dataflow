# %% [markdown]
#  #                                                **Exploring Breathcode data**

# %% [markdown]
# ### Importing necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %% [markdown]
# ### Loading the data

# %%
data = pd.read_csv('../sources/All_Form_Entries.csv', dtype={'utm_content': 'object', 'current_download': 'object', 'state': 'object', 'lead_type': 'object', 'lead_generation_app':'object'})

# %%
data.head()
# Out:
#    Unnamed: 0                        email     id           fullname  \
# 0           0          000000mfg@gmail.com  43721  Martín Fernández
# 1           1           002.juan@gmail.com  21853              Juan
# 2           2            007mike@gmail.com  19125  Michael Lawrence
# 3           3  007zequeirastiven@gmail.com  14018             Niger
# 4           4         010.sergio@gmail.com    982            Sergio
#
#                  course language  \
# 0            full-stack       en
# 1            full-stack       es
# 2            full-stack       en
# 3            full-stack       en
# 4  software-engineering       es
#
#                                              utm_url utm_medium  \
# 0  https://4geeksacademy.com/es/coding-bootcamps/...        NaN
# 1  https://4geeksacademy.com/es/coding-bootcamps/...        NaN
# 2  https://4geeksacademy.com/us/coding-bootcamps/...        NaN
# 3                https://4geeksacademy.com/es/aplica        cpc
# 4  https://4geeksacademy.co/es/course/ingenieria-...        NaN
#
#        utm_campaign        country  ... academy_id deal_status ac_deal_id  \
# 0               NaN         Remote  ...       10.0         NaN    60436.0
# 1               NaN      Venezuela  ...        2.0         NaN    34211.0
# 2               NaN  United States  ...        4.0        LOST    31765.0
# 3  chili-leads-form      Venezuela  ...        7.0         NaN    27642.0
# 4               NaN         Remoto  ...        7.0         NaN        NaN
#
#   won_at lead_generation_app_id  year-month         Day         created_time  \
# 0    NaN                    NaN  2022-07-01  2022-07-29  2022-09-21 08:18:31
# 1    NaN                    NaN  2022-01-01  2022-01-25  2022-09-21 02:43:31
# 2    NaN                    NaN  2021-12-01  2021-12-23  2022-09-21 14:26:04
# 3    NaN                    NaN  2021-10-01  2021-10-08  2022-09-21 01:44:10
# 4    NaN                    NaN  2020-11-01  2020-11-05  2022-09-21 22:43:38
#
#    days_to_convert has_gclid
# 0              NaN         0
# 1              NaN         1
# 2              NaN         0
# 3              NaN         1
# 4              NaN         0
#
# [5 rows x 28 columns]

# %%
data.shape
# Out:
# (46372, 46)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45077 entries, 0 to 45076
# Data columns (total 46 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      45077 non-null  int64
#  1   first_name              44192 non-null  object
#  2   last_name               4339 non-null   object
#  3   email                   45077 non-null  object
#  4   phone                   43419 non-null  float64
#  5   course                  42615 non-null  object
#  6   client_comments         1972 non-null   object
#  7   language                45077 non-null  object
#  8   utm_url                 45016 non-null  object
#  9   utm_medium              18624 non-null  object
#  10  utm_campaign            16879 non-null  object
#  11  street_address          30426 non-null  object
#  12  country                 37591 non-null  object
#  13  city                    37605 non-null  object
#  14  latitude                32953 non-null  float64
#  15  longitude               32953 non-null  float64
#  16  state                   141 non-null    object
#  17  zip_code                23685 non-null  float64
#  18  storage_status          45077 non-null  object
#  19  created_at              45077 non-null  object
#  20  updated_at              45077 non-null  object
#  21  contact_id              0 non-null      float64
#  22  lead_type               101 non-null    object
#  23  location                45015 non-null  object
#  24  referral_key            375 non-null    object
#  25  automations             44943 non-null  object
#  26  tags                    45075 non-null  object
#  27  gclid                   26668 non-null  object
#  28  browser_lang            87 non-null     object
#  29  fb_ad_id                0 non-null      float64
#  30  fb_adgroup_id           0 non-null      float64
#  31  fb_form_id              0 non-null      float64
#  32  fb_leadgen_id           0 non-null      float64
#  33  fb_page_id              0 non-null      float64
#  34  utm_source              19134 non-null  object
#  35  academy_id              44958 non-null  float64
#  36  deal_status             11089 non-null  object
#  37  sentiment               0 non-null      float64
#  38  ac_contact_id           40863 non-null  float64
#  39  ac_deal_id              34129 non-null  float64
#  40  user_id                 1490 non-null   float64
#  41  won_at                  737 non-null    object
#  42  ac_expected_cohort      3 non-null      object
#  43  current_download        155 non-null    object
#  44  lead_generation_app_id  1528 non-null   float64
#  45  utm_content             8733 non-null   object
# dtypes: float64(16), int64(1), object(29)
# memory usage: 15.8+ MB

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# Identifying a very important and our target variable.
#
# Before starting the cleaning of data, we need to identify our target variable to make sure we have it in the correct format.
#
# As we want to know the impact on number of leads that converted to clients we need to use the column 'deal_status' to know which of our leads have the status 'WON'.

# %%
data['deal_status'].value_counts()
# Out:
# LOST    10611
# WON       894
# Name: deal_status, dtype: int64

# %% [markdown]
# **Confirming reliability: Identifying if deal_status has been filled in recent months**

# %%
#create new dataframe
reliability_data = data[['year-month','deal_status']]

# %%
#create a column where filled cells appear as 1 and null cells as 0 

reliability_data['deal_status'] = np.where(data['deal_status'].isnull(), 'not_filled', 'filled')
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_20104\1357308119.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reliability_data['deal_status'] = np.where(data['deal_status'].isnull(), 'not_filled', 'filled')

# %%
reliability_data.head()
# Out:
#   year-month deal_status
# 0    2020-11      filled
# 1    2021-06  not_filled
# 2    2022-04  not_filled
# 3    2020-09  not_filled
# 4    2020-09  not_filled

# %%
reliability_data.set_index('year-month', inplace=True)

# %%
agg = reliability_data.groupby(level=0).deal_status.value_counts().unstack('deal_status')
agg
# Out:
# deal_status  filled  not_filled
# year-month
# 2020-09           2         137
# 2020-10          39         482
# 2020-11          33         522
# 2020-12          47         837
# 2021-01          94         944
# 2021-02         198         850
# 2021-03         201         830
# 2021-04         143         800
# 2021-05         183         618
# 2021-06         293         512
# 2021-07         299         670
# 2021-08         256        1087
# 2021-09         635        1867
# 2021-10         409        1813
# 2021-11         523        1572
# 2021-12         464        1470
# 2022-01         680        2220
# 2022-02        1031        2464
# 2022-03        1276        2125
# 2022-04        1140        2013
# 2022-05        1068        2354
# 2022-06        1111        3385
# 2022-07         926        2374
# 2022-08         454        2921

# %%
from matplotlib import pyplot as plt

fig, ax = plt.subplots(figsize=(10,5))

# First plot the 'Filled' bars for every period.
ax.bar(agg.index, agg['filled'], label='Filled')
# Then plot the 'Not filled' bars on top, starting at the top of the 'Filled'
# bars.
ax.bar(agg.index, agg['not_filled'], bottom=agg['filled'],
       label='Not Filled')
ax.set_title('Is deal status been filled?')
plt.xticks (rotation= 90)
ax.legend()

# %%
#second option to create the graph

reliability_data.groupby(level=0).deal_status.value_counts().unstack('deal_status').plot.bar(stacked=True, figsize=(10,5))

plt.title('Deal_status filled by period')
# Out:
# Text(0.5, 1.0, 'Deal_status filled by period')

# %% [markdown]
# **What pattern can be found in the null deal_ids from Ac?.**

# %%
ab = data[['year-month','ac_deal_id']]

# %%
ab.set_index('year-month')
# Out:
#             ac_deal_id
# year-month
# 2020-11        17526.0
# 2021-06        22887.0
# 2022-04        50098.0
# 2020-09            NaN
# 2020-09            NaN
# ...                ...
# 2022-02        42445.0
# 2022-08        62740.0
# 2022-08        63906.0
# 2022-08        63984.0
# 2022-08        63978.0
#
# [46372 rows x 1 columns]

# %%
# counting null per period for visualization
null_deal_id = ab['ac_deal_id'].isna().groupby(ab['year-month']).sum().reset_index()

# %%
null_deal_id = null_deal_id.set_index('year-month')

# %%
null_deal_id.plot(title="Null deal_id values per month", figsize=(15,6))
# Out:
# <AxesSubplot:title={'center':'Null deal_id values per month'}, xlabel='year-month'>

# %%
null_deal_id.index = pd.to_datetime(null_deal_id.index)

# %% [markdown]
# I shouldn't drop rows with null ac_deal_id because they are clearly not only from the first months of data. Null ac_deal_id are still showing up in 2022 having the largest number of nulls in June 2022.

# %% [markdown]
# **Visualizing target variable**

# %%
#we already have a classification variable but only some are labeled as WON and LOST.
#We will consider all null values and LOST values as 0, and WON values as 1.

data['subscribed'] = np.where(data['deal_status'] == 'WON', '1', '0')

# %%
#This is to replace the notnulls with 1, instead of creating a new column.

#data.loc[data['won_at'].notnull(), 'won_at'] = 1
#data.loc[data['won_at'].isnull(), 'won_at'] = 0

# %%
data['subscribed'].value_counts()
# Out:
# 0    45478
# 1      894
# Name: subscribed, dtype: int64

# %%
target = data.subscribed
features = data.drop('subscribed', axis=1)

# %% [markdown]
# **Visualizing features**

# %%
#Let's create 2 functions to check the categories in categorical features

def countplot_features(df, feature):
    fig = plt.figure(figsize=(10,6))
    ax = sns.countplot(x=df[feature], order=df[feature].value_counts(ascending=False).index);

    abs_values = df[feature].value_counts(ascending=False).values
    ax.bar_label(container=ax.containers[0], labels=abs_values)
    plt.xticks(rotation=30, ha='right')
    #plt.show()

# %%
def countplot_targetvsfeature(df,feature,target):
    fig = plt.figure(figsize=(10,6))
    ax = sns.countplot(x=df[feature], hue=target, order=df[feature].value_counts(ascending=False).index);

    abs_values = df[feature].value_counts(ascending=False).values
    ax.bar_label(container=ax.containers[0], labels=abs_values)
    plt.xticks(rotation=30, ha='right')
    #plt.show()

# %% [markdown]
# 1. Visualizaing courses

# %%
countplot_features(data,'course')

# %% [markdown]
# 2. Visualizing location

# %%
countplot_features(data,'location')

# %% [markdown]
# 3. Visualizing language

# %%
countplot_features(data,'language')

# %% [markdown]
# 4. Visualizing utm_medium

# %%
countplot_features(data,'utm_medium')

# %% [markdown]
# --------> **a way to discover where do this strange labels belong to:**

# %%
data[data['utm_source'] =='hired']['email']
# Out:
# 10299    devoremcintosh@gmail.com
# 27340     neelam.agashe@gmail.com
# 33700        taisublack@gmail.com
# Name: email, dtype: object

# %% [markdown]
# 5. Visualizing utm_source

# %%
countplot_features(data,'utm_source')

# %%
data['utm_source'].value_counts()
# Out:
# google                         7072
# instagram                      4270
# facebook                       4064
# careerkarma                    1423
# landingjobs                     682
# coursereport                    210
# aprendemas                      123
# zoho_recruite                    81
# bing                             48
# ActiveCampaign                   45
# ticjob                           40
# PR?utm_medium=nota-prensa-1      15
# linkedin                          8
# python-es                         7
# qsd.com                           6
# bootcamprankings                  4
# hired                             3
# hs_email                          3
# educaedu                          2
# educaweb                          2
# clubhouse                         1
# test_s                            1
# youtube                           1
# techhub                           1
# women-who-code                    1
# fintech                           1
# Name: utm_source, dtype: int64

# %%
countplot_features(data,'academy_id')

# %% [markdown]
# **--------> a way to discover where do this strange labels belong to:**

# %% [markdown]
# 6. Counting utm_campaign

# %%
data['utm_campaign'].value_counts()
# Out:
# 4Geeks - Prospecting - Clientes Potenciales    1413
# chili-leads-colombia                           1301
# chili-leads-form                                943
# Perfil_Target_Cursos_Programacion_4geeks        777
# 23848776062070343                               749
#                                                ...
# ML + AI                                           1
# Full Stack End of the Year                        1
# techhub-entry-level-expo2022                      1
# Newsletter Abril ESP (Copy)                       1
# VE GeekTALKS 4 de febrero                         1
# Name: utm_campaign, Length: 198, dtype: int64

# %% [markdown]
# 7. Counting Tags

# %%
countplot_features(data,'tags')

# %%
countplot_features(data,'automations')

# %% [markdown]
# **Data from only leads that converted to won**

# %%
won_df = leads_data[leads_data['subscribed'] == "1"]
won_df.head(10)
# Out:
#          id                     first_name                           email  \
# 23     7393          Jesus Bruque Guerrero  bruke3_voleyutrera@hotmail.com
# 55      143                        Vanessa          lamarque.van@gmail.com
# 338     556                          Jorge               uv.mhjl@gmail.com
# 383   32482            Francisco Mandujano   franciscomandujanoe@gmail.com
# 417   22029               stefany albarran           stefa161013@gmail.com
# 422     689                        Kenneth            kparra7491@gmail.com
# 466   26650          Gladys Sánchez Quiroz      gsanchezquiroz@outlook.com
# 858    8323                          Italo       italog.penaloza@gmail.com
# 1086   1376  Felipe Tomás Arancibia Torres     arancibiat.felipe@gmail.com
# 1189   1466                  Alvaro Brante              acbrante@gmail.com
#
#           course language                                            utm_url  \
# 23    full-stack       es                      facebook_form_182669996627327
# 55    full-stack       en                  https://4geeksacademy.co/us/apply
# 338          NaN       en                          https://4geeksacademy.co/
# 383   full-stack       en                https://4geeksacademy.com/es/aplica
# 417   full-stack       en  https://4geeksacademy.com/es/coding-bootcamps/...
# 422   full-stack       en                  https://4geeksacademy.co/us/apply
# 466   full-stack       en  https://4geeksacademy.com/es/coding-bootcamps/...
# 858   full-stack       en            https://4geeksacademy.com/us/financials
# 1086  full-stack       es  https://4geeksacademy.co/es/course/desarrollo-...
# 1189  full-stack       es  https://4geeksacademy.co/es/course/desarrollo-...
#
#      utm_medium                 utm_campaign        country  created_at  ...  \
# 23          cpc  [SIDN] Clientes potenciales            NaN  2021-05-24  ...
# 55          NaN                          NaN            USA  2020-09-24  ...
# 338         NaN                          NaN  United States  2020-10-14  ...
# 383         NaN                          NaN          Chile  2022-04-28  ...
# 417         NaN                          NaN          Spain  2022-01-26  ...
# 422         NaN                          NaN          Spain  2020-10-20  ...
# 466         NaN                          NaN      Venezuela  2022-03-05  ...
# 858         NaN                          NaN          Chile  2021-06-25  ...
# 1086        NaN                          NaN         Remoto  2020-11-26  ...
# 1189        NaN                          NaN          Chile  2020-11-30  ...
#
#      academy_id deal_status ac_contact_id ac_deal_id user_id      won_at  \
# 23          6.0         WON       26268.0    22208.0  4023.0  2021-12-01
# 55          4.0         WON       18291.0    21352.0     NaN  2021-10-19
# 338         4.0         WON       18794.0    16264.0     NaN  2022-05-24
# 383         5.0         WON       47734.0    51022.0  4887.0  2022-06-13
# 417         6.0         WON       38622.0    34365.0     NaN  2022-05-24
# 422         4.0         WON       19138.0    16584.0     NaN  2022-05-24
# 466         2.0         WON       42855.0    45427.0  4880.0  2022-05-03
# 858         5.0         WON       27361.0    22983.0     NaN  2021-08-09
# 1086        7.0         WON       47808.0    51099.0     NaN  2022-05-06
# 1189        5.0         WON       20831.0    28834.0     NaN  2021-10-28
#
#      lead_generation_app_id  subscribed has_gclid  days_to_convert
# 23                      NaN           1         1            191.0
# 55                      NaN           1         0            390.0
# 338                     NaN           1         0            587.0
# 383                     NaN           1         0             46.0
# 417                     NaN           1         0            118.0
# 422                     NaN           1         0            581.0
# 466                     NaN           1         0             59.0
# 858                     NaN           1         0             45.0
# 1086                    NaN           1         0            526.0
# 1189                    NaN           1         0            332.0
#
# [10 rows x 27 columns]

# %%
won_df.shape
# Out:
# (832, 27)

# %% [markdown]
# *Data ready for wons consultations*
# - - - - - - - - - - - - - - - - - -

# %% [markdown]
# # Questions

# %% [markdown]
# ### 1. Leads that came by: organic vs cpc vs referrals (from a thirdparty like course report, careerkarma, etc.)

# %%
countplot_features(leads_data,'utm_medium')

# %%
countplot_features(leads_data,'utm_source')

# %% [markdown]
# ### 2. What are the true labels for utm_source: python-es, qsd.com, techhub, and PR.
# ###          utm_medium: inscripcion.

# %%
leads_data[(leads_data.utm_source == 'PR?utm_medium=nota-prensa-1')]['academy_id']
# Out:
# 6698     10.0
# 10468    10.0
# 10562    10.0
# 10636    10.0
# 10637    10.0
# 10863    10.0
# 12211    10.0
# 14160    10.0
# 14655    10.0
# 14657    10.0
# 14659    10.0
# 16487    10.0
# 18055    10.0
# 18281     6.0
# 18544    10.0
# 21039    10.0
# 28085    10.0
# 32383    10.0
# 34200    10.0
# 34876    10.0
# 35814    10.0
# Name: academy_id, dtype: float64

# %%
leads_data[(leads_data.utm_source == 'python-es')]['academy_id']
# Out:
# 9993     10.0
# 11615    10.0
# 11898    10.0
# 11901    10.0
# 11902    10.0
# 11981    10.0
# 13151    10.0
# 35538    10.0
# 35566    10.0
# Name: academy_id, dtype: float64

# %%
leads_data[(leads_data.utm_source == 'qsd.com')]['academy_id']
# Out:
# 7717     7.0
# 14972    7.0
# 15323    7.0
# 18036    7.0
# 25805    7.0
# 29475    7.0
# 30363    7.0
# 43296    7.0
# Name: academy_id, dtype: float64

# %% [markdown]
# ### 3. Make sure that leads that came from coursereport have referral as utm_medium.

# %%
leads_data[leads_data['utm_source']=='coursereport']
# Out:
#           id              first_name                           email  \
# 253    27285            David Torres         davidtorresc8@gmail.com
# 807     1092         Paul D'Ambrosio             pauld1635@gmail.com
# 932     1198         Carlos Gonzalez             carlossgv@gmail.com
# 1349    1710        Jay Alan Spencer                 jas0123@uah.edu
# 1352   14037            Jazib Jawaid          jawaid.jazib@gmail.com
# ...      ...                     ...                             ...
# 43344  29126  Fahim Hossain Talukder  fahimhossaintalukder@gmail.com
# 43509  30699                John doe         vpn18sam@protonmail.com
# 43853  44597           Peter Irewole            pettoskin@live.co.uk
# 43861  44600              Tom Cruise               cruise@cruise.com
# 45042  22864                    jody         ziterz.gaming@gmail.com
#
#                              course language  \
# 253    machine-learning-engineering       en
# 807                      full-stack       en
# 932                             NaN       es
# 1349                     full-stack       en
# 1352                     full-stack       en
# ...                             ...      ...
# 43344                    full-stack       en
# 43509                    full-stack       en
# 43853          software-engineering       en
# 43861                    full-stack       en
# 45042                    full-stack       en
#
#                                                  utm_url utm_medium  \
# 253    https://4geeksacademy.com/us/coding-bootcamps/...   referral
# 807    https://4geeksacademy.co/us/course/full-stack-...   referral
# 932    https://4geeksacademy.co/es/course/ingenieria-...   referral
# 1349   https://4geeksacademy.co/us/course/full-stack-...   referral
# 1352   https://4geeksacademy.com/us/coding-bootcamps/...   referral
# ...                                                  ...        ...
# 43344  https://4geeksacademy.com/us/coding-bootcamps/...   referral
# 43509  https://4geeksacademy.com/us/coding-bootcamps/...   referral
# 43853  https://4geeksacademy.com/us/coding-bootcamps/...   referral
# 43861  https://4geeksacademy.com/us/coding-bootcamps/...   referral
# 45042  https://4geeksacademy.com/us/coding-bootcamps/...   referral
#
#       utm_campaign        country  created_at  ... academy_id deal_status  \
# 253            NaN         Mexico  2022-03-11  ...        7.0         NaN
# 807            NaN  United States  2020-11-12  ...        4.0         NaN
# 932            NaN          Chile  2020-11-17  ...        5.0         NaN
# 1349           NaN  United States  2020-12-08  ...        7.0         NaN
# 1352           NaN         France  2021-10-08  ...       10.0        LOST
# ...            ...            ...         ...  ...        ...         ...
# 43344          NaN      Australia  2022-03-29  ...        7.0         NaN
# 43509          NaN         France  2022-04-12  ...       10.0         NaN
# 43853          NaN  United States  2022-08-05  ...       11.0        LOST
# 43861          NaN         Remote  2022-08-05  ...       10.0         NaN
# 45042          NaN         Remote  2022-02-03  ...        7.0         NaN
#
#       ac_contact_id ac_deal_id user_id won_at lead_generation_app_id  \
# 253         43371.0    46393.0     NaN    NaT                    NaN
# 807             NaN        NaN     NaN    NaT                    NaN
# 932             NaN        NaN     NaN    NaT                    NaN
# 1349            NaN        NaN     NaN    NaT                    NaN
# 1352        31956.0    39128.0  3974.0    NaT                    NaN
# ...             ...        ...     ...    ...                    ...
# 43344       44899.0    47994.0     NaN    NaT                    NaN
# 43509       46345.0    49538.0     NaN    NaT                    NaN
# 43853       57385.0    61175.0     NaN    NaT                    NaN
# 43861       57388.0    61178.0     NaN    NaT                    NaN
# 45042       39319.0    35069.0     NaN    NaT                    NaN
#
#        subscribed has_gclid  days_to_convert
# 253             0         0              NaN
# 807             0         0              NaN
# 932             0         0              NaN
# 1349            0         0              NaN
# 1352            0         0              NaN
# ...           ...       ...              ...
# 43344           0         0              NaN
# 43509           0         0              NaN
# 43853           0         0              NaN
# 43861           0         0              NaN
# 45042           0         0              NaN
#
# [262 rows x 27 columns]

# %%
#Let's group by utm_source and utm_medium to make sure that leads that came from coursereport, also had referral as utm_medium

leads_data.groupby(['utm_source', 'utm_medium']).size()
# Out:
# utm_source         utm_medium
# 23850705303260143  social                     5
# 23850859616000143  Facebook_Marketplace       1
# 23850859670310143  social                     4
# 4geeks             rrss                      24
# ActiveCampaign     email                     52
# an                 cpc                        1
# aprendemas         referral                 125
# bing               cpc                       57
# bootcamprankings   referral                   4
# careerkarma        referral                1425
# coursereport       referral                 262
# cpc                cpc                        3
# educaedu           referral                   2
# educaweb           referral                   3
# facebook           FB paid                   36
#                    cpc                     4564
#                    social                     2
# google             cpc                     7357
# hired              referral                   1
# hs_email           email                      3
# instagram          cpc                     4222
#                    social                     2
# landingjobs        referral                 777
# linkedin           Inmail                     1
#                    cpc                        3
#                    social                     3
# qsd.com            inscripcion                8
# techhub            event                      1
# test_s             test_m                     2
# ticjob             referral                  23
# youtube            organic                    2
# zoho_recruite      cpc                       81
# dtype: int64

# %% [markdown]
# We can see that 176 leads came from coursereport. The 176 of them have referral assigned to utm_medium.

# %% [markdown]
# ### 4. Make sure that leads that came from careerkarma have referral as utm_medium.

# %%
leads_data[leads_data['utm_source']=='careerkarma']
# Out:
#           id        first_name                       email      course  \
# 140    42462           Purnima   ojhapurnima1992@gmail.com  full-stack
# 229    38369          Mohammad         hossainus@yahoo.com  full-stack
# 291    30949          Jennifer          jqaltman@yahoo.com  full-stack
# 384    30878            Meagan       meaganwavra@gmail.com  full-stack
# 490    31633         Elizabeth        ewarwick20@gmail.com  full-stack
# ...      ...               ...                         ...         ...
# 42383  42445   Sheila Brownlee  sheilabrownlee49@gmail.com  full-stack
# 43420  43100  maxine n whigham     whighammaxine@gmail.com  full-stack
# 43502  44179             Grace         gdjokoto1@gmail.com  full-stack
# 43640  44407           Nia Fox          niafox74@gmail.com  full-stack
# 44852  45616            Lauren        ms.swersky@gmail.com  full-stack
#
#       language                                            utm_url utm_medium  \
# 140         en                                    careerkarma.com   referral
# 229         en                                    careerkarma.com   referral
# 291         en                                    careerkarma.com   referral
# 384         en                                    careerkarma.com   referral
# 490         en                                    careerkarma.com   referral
# ...        ...                                                ...        ...
# 42383       en                                    careerkarma.com   referral
# 43420       en  https://4geeksacademy.com/us/coding-bootcamps/...   referral
# 43502       en                                    careerkarma.com   referral
# 43640       en                 https://4geeksacademy.com/us/apply   referral
# 44852       en                 https://4geeksacademy.com/us/apply   referral
#
#       utm_campaign        country  created_at  ... academy_id deal_status  \
# 140            NaN            NaN  2022-07-16  ...        4.0        LOST
# 229            NaN            NaN  2022-06-18  ...        4.0         NaN
# 291            NaN            NaN  2022-04-14  ...        4.0         NaN
# 384            NaN            NaN  2022-04-13  ...        4.0        LOST
# 490            NaN            NaN  2022-04-21  ...        4.0         NaN
# ...            ...            ...         ...  ...        ...         ...
# 42383          NaN            NaN  2022-07-16  ...        4.0        LOST
# 43420  careerkarma  United States  2022-07-22  ...        7.0         NaN
# 43502          NaN            NaN  2022-08-03  ...        4.0        LOST
# 43640  careerkarma         Mexico  2022-08-04  ...        7.0         NaN
# 44852  careerkarma  United States  2022-08-11  ...        7.0         NaN
#
#       ac_contact_id ac_deal_id user_id won_at lead_generation_app_id  \
# 140         55719.0    59401.0     NaN    NaT                    3.0
# 229         52356.0    55900.0     NaN    NaT                    3.0
# 291         46550.0    49758.0     NaN    NaT                    3.0
# 384         46492.0    49695.0     NaN    NaT                    3.0
# 490         47087.0        NaN     NaN    NaT                    3.0
# ...             ...        ...     ...    ...                    ...
# 42383       55705.0    59385.0     NaN    NaT                    3.0
# 43420       56206.0    59923.0     NaN    NaT                    NaN
# 43502       57030.0    60807.0     NaN    NaT                    3.0
# 43640       57041.0        NaN     NaN    NaT                    NaN
# 44852       58529.0    62272.0     NaN    NaT                    NaN
#
#        subscribed has_gclid  days_to_convert
# 140             0         1              NaN
# 229             0         1              NaN
# 291             0         1              NaN
# 384             0         1              NaN
# 490             0         1              NaN
# ...           ...       ...              ...
# 42383           0         1              NaN
# 43420           0         0              NaN
# 43502           0         1              NaN
# 43640           0         0              NaN
# 44852           0         0              NaN
#
# [1434 rows x 27 columns]

# %%
#Let's group by utm_source and utm_medium to make sure that leads that came from careerkarma, also had referral as utm_medium

leads_data.groupby(['utm_source', 'utm_medium']).size()
# Out:
# utm_source         utm_medium
# 23850705303260143  social                     5
# 23850859616000143  Facebook_Marketplace       1
# 23850859670310143  social                     4
# 4geeks             rrss                      24
# ActiveCampaign     email                     52
# an                 cpc                        1
# aprendemas         referral                 125
# bing               cpc                       57
# bootcamprankings   referral                   4
# careerkarma        referral                1425
# coursereport       referral                 262
# cpc                cpc                        3
# educaedu           referral                   2
# educaweb           referral                   3
# facebook           FB paid                   36
#                    cpc                     4564
#                    social                     2
# google             cpc                     7357
# hired              referral                   1
# hs_email           email                      3
# instagram          cpc                     4222
#                    social                     2
# landingjobs        referral                 777
# linkedin           Inmail                     1
#                    cpc                        3
#                    social                     3
# qsd.com            inscripcion                8
# techhub            event                      1
# test_s             test_m                     2
# ticjob             referral                  23
# youtube            organic                    2
# zoho_recruite      cpc                       81
# dtype: int64

# %% [markdown]
# From the 549 leads that came from careerkarma, 542 have referral as utm_medium. The rest do not have utm_medium filled.

# %%
#Let's fill those 7 rows with utm_medium 'referral'.

leads_data['utm_medium'] = np.where((leads_data['utm_source'] == 'careerkarma') & (leads_data['utm_medium'] == '') ,
                              'referral',data['utm_medium'])

# %% [markdown]
# ### 5. Difference between deal_status and won_at

# %%
leads_data['with_contract'] = np.where(leads_data['won_at'].isnull(), '0', '1')

# %%
countplot_targetvsfeature(leads_data,'subscribed',leads_data['with_contract'])

# %%
leads_data['with_contract'].value_counts()
# Out:
# 0    44340
# 1      737
# Name: with_contract, dtype: int64

# %% [markdown]
# There are 832 leads that subscribed, from which only 737 appear with a contract date ('signed_contract') and the other 76 do not have any date filled.
#
# *By may there were 509 subscribed and 433 with contract date*

# %% [markdown]
# ### 6. Analize lead_generation_app_id

# %%
countplot_features(leads_data,'lead_generation_app_id')

# %%
leads_data.groupby(['lead_generation_app_id', 'utm_medium','utm_source']).size()
# Out:
# lead_generation_app_id  utm_medium  utm_source
# 1.0                     referral    aprendemas      125
# 2.0                     referral    educaedu          2
#                                     educaweb          3
# 3.0                     referral    careerkarma    1398
# dtype: int64

# %%
#How many of those previous leads did convert into a client?

won_df['lead_generation_app_id'].value_counts()
# Out:
# 3.0    14
# 1.0     1
# Name: lead_generation_app_id, dtype: int64

# %% [markdown]
# CareerKarma is bringing more leads compared to the other 2 lead_generation apps, and has already converted 14 leads. (2 until May)

# %% [markdown]
# ### 7. Make sure landingjobs in utm_source is assigned to utm_medium = referral

# %%
leads_data[leads_data['utm_source']=='landingjobs']
# Out:
#           id               first_name                            email  \
# 1518   11946  Ainhoa Palacio Gonzalez          ainhoapalacio@gmail.com
# 1519   13463              Solomon Soh             sohzhehong@gmail.com
# 1539   13490           Nazareno Costa              nazarenoc@gmail.com
# 1561   12000           Alina Carvalho       alina.carvalho84@gmail.com
# 1624   11897                Francesco   francesco.baldissera@gmail.com
# ...      ...                      ...                              ...
# 41941  13558    Themistoklis Sevastos                 sevthem@yahoo.gr
# 41961  12191           Fabiano Pessôa  fabiano.pessoa@pensiero.digital
# 42813  12123           Erica Escudero         solenergia2017@gmail.com
# 42832  12060      Apostolos Giatsidis           ap.giatsidis@gmail.com
# 42833  11753    German Gustavo Bertea              gerbertea@gmail.com
#
#                              course language  \
# 1518                     full-stack       en
# 1519   machine-learning-engineering       en
# 1539   machine-learning-engineering       en
# 1561                     full-stack       en
# 1624   machine-learning-engineering       en
# ...                             ...      ...
# 41941                    full-stack       en
# 41961  machine-learning-engineering       en
# 42813  machine-learning-engineering       en
# 42832  machine-learning-engineering       en
# 42833  machine-learning-engineering       en
#
#                                                  utm_url utm_medium  \
# 1518   https://4geeksacademy.com/us/landing/scholarsh...   referral
# 1519   https://4geeksacademy.com/us/landing/scholarsh...   referral
# 1539   https://4geeksacademy.com/us/landing/scholarsh...   referral
# 1561   https://4geeksacademy.com/us/landing/scholarsh...   referral
# 1624   https://4geeksacademy.com/es/landing/becas-lan...   referral
# ...                                                  ...        ...
# 41941  https://4geeksacademy.com/us/landing/scholarsh...   referral
# 41961  https://4geeksacademy.com/us/landing/scholarsh...   referral
# 42813  https://4geeksacademy.com/es/landing/becas-lan...   referral
# 42832  https://4geeksacademy.com/us/landing/scholarsh...   referral
# 42833  https://4geeksacademy.com/es/landing/becas-lan...   referral
#
#       utm_campaign country  created_at  ... deal_status ac_contact_id  \
# 1518           NaN  France  2021-09-14  ...         NaN       30457.0
# 1519           NaN  France  2021-10-02  ...         NaN       31699.0
# 1539           NaN  France  2021-10-02  ...        LOST       31721.0
# 1561           NaN  France  2021-09-14  ...        LOST       30499.0
# 1624           NaN  France  2021-09-14  ...        LOST       30410.0
# ...            ...     ...         ...  ...         ...           ...
# 41941          NaN  France  2021-10-02  ...        LOST       31774.0
# 41961          NaN  France  2021-09-15  ...        LOST       30665.0
# 42813          NaN  France  2021-09-15  ...         NaN       30603.0
# 42832          NaN  France  2021-09-14  ...         NaN       30550.0
# 42833          NaN  France  2021-09-14  ...         NaN       30274.0
#
#       ac_deal_id user_id won_at lead_generation_app_id subscribed  has_gclid  \
# 1518     25916.0     NaN    NaT                    NaN          0          0
# 1519     27206.0     NaN    NaT                    NaN          0          0
# 1539     27227.0     NaN    NaT                    NaN          0          0
# 1561     25958.0     NaN    NaT                    NaN          0          0
# 1624     25869.0     NaN    NaT                    NaN          0          0
# ...          ...     ...    ...                    ...        ...        ...
# 41941    27279.0     NaN    NaT                    NaN          0          0
# 41961    26126.0     NaN    NaT                    NaN          0          0
# 42813    26065.0     NaN    NaT                    NaN          0          0
# 42832    26010.0     NaN    NaT                    NaN          0          0
# 42833    25734.0     NaN    NaT                    NaN          0          0
#
#       days_to_convert  with_contract
# 1518              NaN              0
# 1519              NaN              0
# 1539              NaN              0
# 1561              NaN              0
# 1624              NaN              0
# ...               ...            ...
# 41941             NaN              0
# 41961             NaN              0
# 42813             NaN              0
# 42832             NaN              0
# 42833             NaN              0
#
# [777 rows x 28 columns]

# %%
leads_data.groupby(['utm_medium', 'utm_source']).size()
# Out:
# utm_medium            utm_source
# FB paid               facebook               36
# Facebook_Marketplace  23850859616000143       1
# Inmail                linkedin                1
# cpc                   an                      1
#                       bing                   57
#                       cpc                     3
#                       facebook             4564
#                       google               7357
#                       instagram            4222
#                       linkedin                3
#                       zoho_recruite          81
# email                 ActiveCampaign         52
#                       hs_email                3
# event                 techhub                 1
# inscripcion           qsd.com                 8
# organic               youtube                 2
# referral              aprendemas            125
#                       bootcamprankings        4
#                       careerkarma          1425
#                       coursereport          262
#                       educaedu                2
#                       educaweb                3
#                       hired                   1
#                       landingjobs           777
#                       ticjob                 23
# rrss                  4geeks                 24
# social                23850705303260143       5
#                       23850859670310143       4
#                       facebook                2
#                       instagram               2
#                       linkedin                3
# test_m                test_s                  2
# dtype: int64

# %% [markdown]
# All utm_source = landingjobs are appearing with referral in utm_medium.

# %% [markdown]
# ### 8. Conversion time from leads that did not drop

# %%
contracts = leads_data[leads_data['with_contract']=='1']
contracts_df = pd.DataFrame(contracts)

# %%
#Time in days since first contact until signing a contract.

stat_contracts = contracts_df['days_to_convert'].describe()
print(stat_contracts)
# Out:
# count    737.000000
# mean      76.202171
# std      104.260966
# min        0.000000
# 25%       10.000000
# 50%       43.000000
# 75%       84.000000
# max      590.000000
# Name: days_to_convert, dtype: float64

# %%
plt.figure(figsize=(6,6))
sns.boxplot(data=leads_data['days_to_convert'])
plt.title('Visualizaing the outliers in days_to_convert')
plt.ylabel('Days')
# Out:
# Text(0, 0.5, 'Days')

# %%
#Now let's see where do all those leads that didn't drop came from.

contracts_df['utm_source'].value_counts()
# Out:
# google          130
# instagram        33
# facebook         30
# careerkarma      14
# landingjobs       8
# coursereport      7
# aprendemas        1
# linkedin          1
# ticjob            1
# Name: utm_source, dtype: int64

# %%
#Now we will do the same analysis as before but considering all the won status (even if they do not have a contract date)

won_df['utm_source'].value_counts()
# Out:
# google          147
# facebook         38
# instagram        37
# careerkarma      14
# landingjobs       9
# coursereport      7
# bing              1
# aprendemas        1
# linkedin          1
# ticjob            1
# Name: utm_source, dtype: int64

# %% [markdown]
# ### 9. How many wons are that did not come from cpc?

# %%
won_df['utm_medium'].value_counts()
# Out:
# cpc         223
# referral     34
# social        1
# Name: utm_medium, dtype: int64

# %% [markdown]
# From the leads marked as won, 10% are not from cpc.

# %% [markdown]
# ### 10. Check if WONS have newsletter besides request_more_info in TAGS.

# %%
won_df['tags'].value_counts()
# Out:
# website-lead                         467
# request_more_info                    334
# utec-uruguay                          16
# contact-us                            10
# newsletter                             3
# website-lead,blacks-in-technology      2
# Name: tags, dtype: int64

# %% [markdown]
# The people who subscribed have mainly the 'website-lead' and 'request_more_info' tag. But they do not have newsletter besides 'request_more_info'.

# %% [markdown]
# ### 11. Make sure Spain is filling won_at (contract_date)

# %%
won_df.loc[(won_df['academy_id'] == 6.0) & won_df['won_at'].isnull()]
# Out:
#           id                first_name                          email  \
# 5190    5832         Javier L. Seiglie             jseiglie@gmail.com
# 5280    7153    Florence Paloma Gaspar       f.palomagaspar@gmail.com
# 6038    6754              Nita Gabriel           gabyiy2000@yahoo.com
# 6652    6939                      pepe         bryan_2904@hotmail.com
# 7111    7881        Isaac Ruiz Gavilán          isaacrg1996@gmail.com
# 7233    9599          Adrian Gualsaqui    adriangualsaqui@hotmail.com
# 11118  23988                   Enrique               egl12@hotmail.es
# 11763   9118              Gloria Silva        imgloriasilva@gmail.com
# 11772   8843         Rubén López Magán          rublopmag@hotmail.com
# 14776  24696  Sergio Centenera Mayoral             scentmay@gmail.com
# 15494  15792   Alfonso Carretero Pérez          alfonsocp10@gmail.com
# 17547  17684  Jose Luis Medina tortosa    josemedinatortosa@gmail.com
# 18257  18316         Joana Mateos Ares        joanamateos@hotmail.com
# 18567  18442      Sergi Madrigal Gómez             Lvsyan96@gmail.com
# 19170  32352                     Tomas         tomasxherman@gmail.com
# 19383  19112    Jorge Luis Leon Bolaño     jorgeleonpicture@gmail.com
# 19826  19955                    Angela          angela.qf@hotmail.com
# 20631  18811           Daniel Gaiteiro            dgaiteiro@gmail.com
# 21487   1453       Daniel Santa-Olalla             therbero@gmail.com
# 23217  21818     Daniela Angulo Martin      Dani.angulo1910@gmail.com
# 28617  20617            Javier Jiménez  javijimenezclemente@gmail.com
# 29276  26915         Débora Díaz Pérez        deboradiazper@gmail.com
# 30225  13758                  Cornelio      cornelio.diaz@outlook.com
# 31087  29996      Manuel Lopez Martret           manulm27@hotmail.com
# 32962  23733                    Isabel        isagalo1980@outlook.com
# 35984  38847              Fran Martín   Martinhernandez.fj@gmail.com
# 40828  27670                    Xavier         xavierwblack@gmail.com
#
#                              course language  \
# 5190                     full-stack       es
# 5280                     full-stack       es
# 6038                     full-stack       es
# 6652                     full-stack       en
# 7111                     full-stack       en
# 7233                     full-stack       es
# 11118  machine-learning-engineering       en
# 11763                    full-stack       en
# 11772                    full-stack       en
# 14776                    full-stack       es
# 15494                    full-stack       es
# 17547                    full-stack       en
# 18257                    full-stack       en
# 18567                    full-stack       en
# 19170                    full-stack       en
# 19383                    full-stack       en
# 19826                    full-stack       en
# 20631                    full-stack       en
# 21487                    full-stack       en
# 23217                    full-stack       en
# 28617                    full-stack       en
# 29276                    full-stack       en
# 30225  machine-learning-engineering       en
# 31087                    full-stack       es
# 32962                    full-stack       en
# 35984                    full-stack       es
# 40828                    full-stack       en
#
#                                                  utm_url utm_medium  \
# 5190                       facebook_form_182669996627327        cpc
# 5280                       facebook_form_182669996627327        cpc
# 6038                       facebook_form_182669996627327        cpc
# 6652   https://4geeksacademy.com/es/coding-bootcamps/...        cpc
# 7111   https://4geeksacademy.com/us/coding-bootcamps/...        NaN
# 7233                       facebook_form_182669996627327        cpc
# 11118                 https://4geeksacademy.com/us/apply        NaN
# 11763                https://4geeksacademy.com/es/aplica        NaN
# 11772  https://4geeksacademy.com/es/coding-bootcamps/...        NaN
# 14776                      facebook_form_182669996627327        cpc
# 15494                      facebook_form_182669996627327        cpc
# 17547  https://4geeksacademy.com/es/coding-bootcamps/...        NaN
# 18257  https://4geeksacademy.com/es/coding-bootcamps/...        NaN
# 18567  https://4geeksacademy.com/es/coding-bootcamps/...        NaN
# 19170                https://4geeksacademy.com/es/aplica        NaN
# 19383                https://4geeksacademy.com/es/aplica        NaN
# 19826  https://4geeksacademy.com/es/coding-bootcamps/...        NaN
# 20631  https://4geeksacademy.com/es/coding-bootcamps/...        cpc
# 21487  https://4geeksacademy.co/es/landing/aprende-a-...        NaN
# 23217                https://4geeksacademy.com/es/aplica        NaN
# 28617  https://4geeksacademy.com/es/coding-bootcamps/...        cpc
# 29276  https://4geeksacademy.com/es/coding-bootcamps/...        cpc
# 30225  https://4geeksacademy.com/es/coding-bootcamps/...        cpc
# 31087                      facebook_form_182669996627327        cpc
# 32962  https://4geeksacademy.com/es/coding-bootcamps/...        cpc
# 35984                      facebook_form_182669996627327        cpc
# 40828       https://4geeksacademy.com/es/proximas-fechas        cpc
#
#                                       utm_campaign    country  created_at  \
# 5190                   [SIDN] Clientes potenciales        NaN  2021-04-03
# 5280                   [SIDN] Clientes potenciales        NaN  2021-05-14
# 6038                   [SIDN] Clientes potenciales        NaN  2021-04-30
# 6652                                   10503661130      Spain  2021-05-05
# 7111                                           NaN      Spain  2021-06-10
# 7233   4Geeks - Prospecting - Clientes Potenciales        NaN  2021-08-04
# 11118                                          NaN      Spain  2022-02-12
# 11763                                          NaN      Spain  2021-07-22
# 11772                                          NaN      Spain  2021-07-14
# 14776  4Geeks - Prospecting - Clientes Potenciales        NaN  2022-02-17
# 15494  4Geeks - Prospecting - Clientes Potenciales        NaN  2021-11-03
# 17547                                          NaN      Spain  2021-11-30
# 18257                                          NaN      Spain  2021-12-10
# 18567                                          NaN      Spain  2021-12-13
# 19170                                          NaN  Argentina  2022-04-27
# 19383                                          NaN      Spain  2021-12-23
# 19826                                          NaN      Spain  2022-01-04
# 20631                                  10503661130      Spain  2021-12-18
# 21487                                          NaN      Spain  2020-11-30
# 23217                                          NaN      Spain  2022-01-24
# 28617                                  10503661130      Spain  2022-01-12
# 29276                                  13032913419      Spain  2022-03-08
# 30225                                  12321016929      Spain  2021-10-05
# 31087  4Geeks - Prospecting - Clientes Potenciales        NaN  2022-04-05
# 32962                                  15831311726      Spain  2022-02-10
# 35984  4Geeks - Prospecting - Clientes Potenciales        NaN  2022-06-22
# 40828                                  10503661130      Spain  2022-03-15
#
#        ... academy_id deal_status ac_contact_id ac_deal_id user_id won_at  \
# 5190   ...        6.0         WON       25010.0    21081.0     NaN    NaT
# 5280   ...        6.0         WON       25986.0    22022.0  3503.0    NaT
# 6038   ...        6.0         WON       25676.0    21708.0     NaN    NaT
# 6652   ...        6.0         WON       25626.0    21665.0  3467.0    NaT
# 7111   ...        6.0         WON       26974.0    22638.0  3610.0    NaT
# 7233   ...        6.0         WON       28509.0    23968.0  3725.0    NaT
# 11118  ...        6.0         WON       40679.0    40158.0  4480.0    NaT
# 11763  ...        6.0         WON       28025.0    23617.0  3853.0    NaT
# 11772  ...        6.0         WON       26982.0    22648.0  3734.0    NaT
# 14776  ...        6.0         WON       41227.0    41574.0  4744.0    NaT
# 15494  ...        6.0         WON       33582.0    29149.0  4087.0    NaT
# 17547  ...        6.0         WON       33306.0    30645.0  4184.0    NaT
# 18257  ...        6.0         WON       35586.0    31135.0  4357.0    NaT
# 18567  ...        6.0         WON       35497.0    31248.0     NaN    NaT
# 19170  ...        6.0         WON       47650.0    50920.0  5042.0    NaT
# 19383  ...        6.0         WON       36163.0    31759.0  4329.0    NaT
# 19826  ...        6.0         WON       36796.0    32440.0  4367.0    NaT
# 20631  ...        6.0         WON       35961.0    31539.0  4263.0    NaT
# 21487  ...        6.0         WON       20815.0    17554.0     NaN    NaT
# 23217  ...        6.0         WON       15528.0    12557.0     NaN    NaT
# 28617  ...        6.0         WON       37299.0    32978.0  4398.0    NaT
# 29276  ...        6.0         WON       43058.0    45646.0  4588.0    NaT
# 30225  ...        6.0         WON       31932.0    27447.0  5045.0    NaT
# 31087  ...        6.0         WON       45724.0    48870.0     NaN    NaT
# 32962  ...        6.0         WON       40452.0    38192.0  4469.0    NaT
# 35984  ...        6.0         WON       52829.0    56344.0     NaN    NaT
# 40828  ...        6.0         WON       43697.0    47028.0  4599.0    NaT
#
#       lead_generation_app_id  subscribed has_gclid  days_to_convert
# 5190                     NaN           1         1              NaN
# 5280                     NaN           1         1              NaN
# 6038                     NaN           1         1              NaN
# 6652                     NaN           1         1              NaN
# 7111                     NaN           1         0              NaN
# 7233                     NaN           1         1              NaN
# 11118                    NaN           1         0              NaN
# 11763                    NaN           1         0              NaN
# 11772                    NaN           1         0              NaN
# 14776                    NaN           1         1              NaN
# 15494                    NaN           1         1              NaN
# 17547                    NaN           1         0              NaN
# 18257                    NaN           1         0              NaN
# 18567                    NaN           1         0              NaN
# 19170                    NaN           1         0              NaN
# 19383                    NaN           1         0              NaN
# 19826                    NaN           1         0              NaN
# 20631                    NaN           1         1              NaN
# 21487                    NaN           1         1              NaN
# 23217                    NaN           1         0              NaN
# 28617                    NaN           1         1              NaN
# 29276                    NaN           1         1              NaN
# 30225                    NaN           1         1              NaN
# 31087                    NaN           1         1              NaN
# 32962                    NaN           1         1              NaN
# 35984                    NaN           1         1              NaN
# 40828                    NaN           1         1              NaN
#
# [27 rows x 27 columns]

# %% [markdown]
# There are 109 leads labeled as WON in Spain academy, and from them there are 91 with a signed contract.
# 18 leads without a contract date. 3 of them have been updated on March 21st).

# %% [markdown]
# ### 12. Verify if leads coming from facebook and google that have cpc assigned but no gclid are from past years.

# %%
#facebook

data[(data.utm_source == 'facebook') & (data.has_gclid == '0') & (data.utm_medium == 'cpc')]['created_at'].value_counts()
# Out:
# 2022-07-11    8
# 2022-07-08    4
# 2021-02-09    3
# 2022-07-10    3
# 2021-02-07    3
#              ..
# 2022-01-26    1
# 2022-01-31    1
# 2022-01-18    1
# 2021-12-29    1
# 2022-08-10    1
# Name: created_at, Length: 85, dtype: int64

# %%
#google

data[(data.utm_source == 'google') & (data.has_gclid == '0') & (data.utm_medium == 'cpc')]['created_at'].value_counts()
# Out:
# 2022-04-01    5
# 2022-06-06    4
# 2022-07-30    4
# 2022-08-13    3
# 2021-08-15    3
#              ..
# 2022-07-27    1
# 2021-09-22    1
# 2022-04-12    1
# 2022-05-12    1
# 2022-05-11    1
# Name: created_at, Length: 125, dtype: int64

# %% [markdown]
# ### 13. Analize repeated leads.

# %%
duplicated_rows_df = leads_data[leads_data.duplicated(['email'])]

# %%
duplicated_rows_df
# Out:
#           id                           first_name  \
# 17       178                               Janice
# 29       150                               Adrian
# 30       169                                 José
# 32        99                             Patricia
# 33       115                             Patricia
# ...      ...                                  ...
# 45064  45795  ANDRES EDUARDO SEPULVEDA NASCIMENTO
# 45066  45805             Javier Mauricio Restrepo
# 45070  45802                                  NaN
# 45072  45664              Maydana Hernan Exequiel
# 45076  45807            Ismael Ernesto Moreno Noy
#
#                              email                course language  \
# 17             rosnice17@gmail.com  software-engineering       es
# 29       adrian_amesty@hotmail.com            full-stack       es
# 30            josemfcheo@gmail.com  software-engineering       es
# 32          2231valemati@gmail.com            full-stack       es
# 33          2231valemati@gmail.com                   NaN       es
# ...                            ...                   ...      ...
# 45064          SEPU_94@HOTMAIL.COM            full-stack       en
# 45066       maoresquigua@gmail.com            full-stack       en
# 45070       maoresquigua@gmail.com                   NaN       en
# 45072         maydanarkt@gmail.com            full-stack       en
# 45076  iernestomorenonoy@gmail.com            full-stack       es
#
#                                                  utm_url utm_medium  \
# 17     https://4geeksacademy.co/us/course/software-en...        NaN
# 29                    https://4geeksacademy.co/es/aplica        NaN
# 30     https://4geeksacademy.co/us/course/software-en...        NaN
# 32     https://4geeksacademy.co/es/course/desarrollo-...        NaN
# 33     https://4geeksacademy.co/us/location/online-re...        NaN
# ...                                                  ...        ...
# 45064                https://4geeksacademy.com/es/aplica        cpc
# 45066                https://4geeksacademy.com/es/aplica        cpc
# 45070               https://4geeksacademy.com/es/premios        cpc
# 45072                https://4geeksacademy.com/es/aplica        NaN
# 45076                      facebook_form_182669996627327        cpc
#
#                                       utm_campaign    country  created_at  \
# 17                                             NaN     Remote  2020-09-25
# 29                                             NaN  Venezuela  2020-09-24
# 30                                             NaN  Venezuela  2020-09-25
# 32                                             NaN  Venezuela  2020-09-22
# 33                                             NaN  Venezuela  2020-09-22
# ...                                            ...        ...         ...
# 45064                                  13032913419      Spain  2022-08-13
# 45066                       chili-trafico-colombia   Colombia  2022-08-13
# 45070                       chili-trafico-colombia   Colombia  2022-08-13
# 45072                                          NaN  Argentina  2022-08-11
# 45076  4Geeks - Prospecting - Clientes Potenciales        NaN  2022-08-13
#
#        ... deal_status ac_contact_id ac_deal_id user_id won_at  \
# 17     ...         NaN           NaN        NaN     NaN    NaT
# 29     ...         NaN           NaN        NaN     NaN    NaT
# 30     ...         NaN           NaN        NaN     NaN    NaT
# 32     ...         NaN           NaN        NaN     NaN    NaT
# 33     ...         NaN           NaN        NaN     NaN    NaT
# ...    ...         ...           ...        ...     ...    ...
# 45064  ...         NaN       51799.0        NaN     NaN    NaT
# 45066  ...         NaN       58736.0    62497.0     NaN    NaT
# 45070  ...         NaN       58736.0        NaN     NaN    NaT
# 45072  ...         NaN       58595.0    62344.0     NaN    NaT
# 45076  ...         NaN       58739.0        NaN     NaN    NaT
#
#       lead_generation_app_id subscribed  has_gclid days_to_convert  \
# 17                       NaN          0          0             NaN
# 29                       NaN          0          0             NaN
# 30                       NaN          0          0             NaN
# 32                       NaN          0          0             NaN
# 33                       NaN          0          0             NaN
# ...                      ...        ...        ...             ...
# 45064                    NaN          0          0             NaN
# 45066                    NaN          0          1             NaN
# 45070                    NaN          0          1             NaN
# 45072                    NaN          0          0             NaN
# 45076                    NaN          0          1             NaN
#
#        with_contract
# 17                 0
# 29                 0
# 30                 0
# 32                 0
# 33                 0
# ...              ...
# 45064              0
# 45066              0
# 45070              0
# 45072              0
# 45076              0
#
# [11232 rows x 28 columns]

# %%
duplicated_rows_df.shape
# Out:
# (11232, 28)

# %%
repeated_leads = duplicated_rows_df.groupby(['email','created_at']).size()
repeated_df = pd.DataFrame(repeated_leads)

# %%
repeated_df
# Out:
#                                         0
# email                       created_at
# 010.sergio@gmail.com        2020-11-09  1
# 02sergioconde@gmail.com     2021-11-02  1
#                             2022-03-28  1
#                             2022-03-30  1
# 07.ebad@gmail.com           2022-06-29  1
# ...                                    ..
# zuberlye@gmail.com          2022-03-03  1
# zuckaschilling@gmail.com    2022-05-07  1
# zuluaganeider@gmail.com     2022-04-27  1
# zumanzuesaubrey29@gmail.com 2022-05-17  1
# zunigasm.ariel@gmail.com    2021-08-03  2
#
# [8972 rows x 1 columns]
